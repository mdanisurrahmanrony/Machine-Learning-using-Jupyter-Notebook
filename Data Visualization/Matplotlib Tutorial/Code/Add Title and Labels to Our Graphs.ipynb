# %%
from matplotlib import pyplot as plt

# %%
x=[5,8,10]
y=[12,16,6]

# %%
plt.plot(x,y)
plt.title('info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
plt.show()
